# %% [markdown]
# <a href="https://colab.research.google.com/github/HyunVinh/AI/blob/main/money.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import pandas as pd
import seaborn as ses
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score,recall_score,confusion_matrix,classification_report,accuracy_score,f1_score


from keras.layers import Dense, Activation, Dropout, BatchNormalization, LSTM,Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical ,load_img, img_to_array
from tensorflow.keras.optimizers import RMSprop,SGD
from tensorflow.keras.models import load_model
from keras import callbacks
from keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
folder = '/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/train/100k/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'c' + str(i) + '.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
model=Sequential() #CNN
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(200,200,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2))) # tìm giá trị lớn nhất trong ma trận 8x8 để làm cho ảnh có độ nổi lên
model.add(Dropout(0.25))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten()) #ANN
model.add(Dense(128,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(11,activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  batch_normalization (BatchN  (None, 198, 198, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  dropout (Dropout)           (None, 99, 99, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 97, 97, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 46, 46, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 23, 23, 128)       0
#
# ...

# %%
image_generator = ImageDataGenerator(rotation_range=15,
                                rescale=1./255,
                                shear_range=0.1,
                                zoom_range=0.2,
                                horizontal_flip=True,
                                width_shift_range=0.1,
                                height_shift_range=0.1
                                )   

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/train/',
                                                 shuffle=True,
                                                 target_size=(200, 200), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/test/',
                                                 shuffle=True,
                                                 target_size=(200, 200), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 165 images belonging to 11 classes.
# Found 0 images belonging to 11 classes.

# %%
history=model.fit(train_dataset,batch_size=10,epochs=50,verbose=1,
                  validation_data=validation_dataset)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 3s 185ms/step - loss: 0.2041 - accuracy: 0.9394
# Epoch 2/50
# 17/17 [==============================] - 3s 185ms/step - loss: 0.3087 - accuracy: 0.8970
# Epoch 3/50
# 17/17 [==============================] - 3s 183ms/step - loss: 0.3039 - accuracy: 0.9152
# Epoch 4/50
# 17/17 [==============================] - 3s 196ms/step - loss: 0.1997 - accuracy: 0.9515
# Epoch 5/50
# 17/17 [==============================] - 3s 188ms/step - loss: 0.1856 - accuracy: 0.9394
# Epoch 6/50
# 17/17 [==============================] - 3s 190ms/step - loss: 0.3568 - accuracy: 0.9030
# Epoch 7/50
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2041 - accuracy: 0.9152
# Epoch 8/50
# 17/17 [==============================] - 3s 189ms/step - loss: 0.2574 - accuracy: 0.9212
# Epoch 9/50
# 17/17 [==============================] - 3s 192ms/step - loss: 0.2721 - accuracy: 0.9030
# Epoch 10/50
# ...

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/test/500k/a1.jpg'  

img = mpimg.imread(filename)
imgplot = plt.imshow(img)
plt.show()

img = load_img(filename,target_size = (200,200))
img = img_to_array(img)
img =  img.reshape(1,200,200,3)
img = img.astype('float32')
img = img/255
kq = np.argmax(model.predict(img),axis= -1)
if kq==0:
  print('Day la 100')
elif kq ==1:
  print('Day la  100k')
elif kq ==2:
  print('Day la  10k')
elif kq ==3:
  print('Day la  1k')
elif kq ==4:
  print('Day la  200')
elif kq ==5:
  print('Day la 200k')
elif kq ==6:
  print('Day la 2k')
elif kq ==7:
  print('Day la 500')
elif kq ==8:
  print('Day la 500k')
elif kq ==9:
  print('Day la 50k')
elif kq ==10:
  print('Day la 5k')
# Out:
# Day la 500k

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/test/1k/b2.jpg'  

img = mpimg.imread(filename)
imgplot = plt.imshow(img)
plt.show()

img = load_img(filename,target_size = (200,200))
img = img_to_array(img)
img =  img.reshape(1,200,200,3)
img = img.astype('float32')
img = img/255
kq = np.argmax(model.predict(img),axis= -1)
if kq==0:
  print('Day la 100')
elif kq ==1:
  print('Day la  100k')
elif kq ==2:
  print('Day la  10k')
elif kq ==3:
  print('Day la  1k')
elif kq ==4:
  print('Day la  200')
elif kq ==5:
  print('Day la 200k')
elif kq ==6:
  print('Day la 2k')
elif kq ==7:
  print('Day la 500')
elif kq ==8:
  print('Day la 500k')
elif kq ==9:
  print('Day la 50k')
elif kq ==10:
  print('Day la 5k')
# Out:
# Day la  1k

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/test/50k/d3.jpg'  

img = mpimg.imread(filename)
imgplot = plt.imshow(img)
plt.show()

img = load_img(filename,target_size = (200,200))
img = img_to_array(img)
img =  img.reshape(1,200,200,3)
img = img.astype('float32')
img = img/255
kq = np.argmax(model.predict(img),axis= -1)
if kq==0:
  print('Day la 100')
elif kq ==1:
  print('Day la  100k')
elif kq ==2:
  print('Day la  10k')
elif kq ==3:
  print('Day la  1k')
elif kq ==4:
  print('Day la  200')
elif kq ==5:
  print('Day la 200k')
elif kq ==6:
  print('Day la 2k')
elif kq ==7:
  print('Day la 500')
elif kq ==8:
  print('Day la 500k')
elif kq ==9:
  print('Day la 50k')
elif kq ==10:
  print('Day la 5k')
# Out:
# Day la 50k

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/data-tien-vietnam/test/200k/v3.jpg'  

img = mpimg.imread(filename)
imgplot = plt.imshow(img)
plt.show()

img = load_img(filename,target_size = (200,200))
img = img_to_array(img)
img =  img.reshape(1,200,200,3)
img = img.astype('float32')
img = img/255
kq = np.argmax(model.predict(img),axis= -1)
if kq==0:
  print('Day la 100')
elif kq ==1:
  print('Day la  100k')
elif kq ==2:
  print('Day la  10k')
elif kq ==3:
  print('Day la  1k')
elif kq ==4:
  print('Day la  200')
elif kq ==5:
  print('Day la 200k')
elif kq ==6:
  print('Day la 2k')
elif kq ==7:
  print('Day la 500')
elif kq ==8:
  print('Day la 500k')
elif kq ==9:
  print('Day la 50k')
elif kq ==10:
  print('Day la 5k')
# Out:
# Day la 200k
